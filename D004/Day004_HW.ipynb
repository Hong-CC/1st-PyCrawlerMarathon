# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
# r.text
import requests
r = requests.get('http://odata.wra.gov.tw/v4/RealtimeWaterLevel')
r.text
# Out:
# '{"@odata.context": "http://odata.wra.gov.tw/v4/$metadata#RealtimeWaterLevel",\n"@odata.count": 100,\n"value": [{"StationIdentifier": "1730H077","RecordTime": "Nov 28, 2019 1:00:00 AM","WaterLevel": 740.46},{"StationIdentifier": "2560H024","RecordTime": "Nov 28, 2019 1:00:00 AM","WaterLevel": 202.6},{"StationIdentifier": "1740H002","RecordTime": "Nov 28, 2019 12:50:00 AM","WaterLevel": 4.41},{"StationIdentifier": "1730H074","RecordTime": "Nov 28, 2019 1:00:00 AM","WaterLevel": 245.47},{"StationIdentifier": "2560H020","RecordTime": "Nov 28, 2019 1:00:00 AM","WaterLevel": -0.37},{"StationIdentifier": "1630H040","RecordTime": "Nov 28, 2019 1:00:00 AM","WaterLevel": 1.78},{"StationIdentifier": "1730H070","RecordTime": "Nov 28, 2019 1:00:00 AM","WaterLevel": 226.21},{"StationIdentifier": "2560H023","RecordTime": "Nov 28, 2019 1:00:00 AM","WaterLevel": 13.04},{"StationIdentifier": "1730H072","RecordTime": "Nov 28, 2019 1:00:00 AM","WaterLevel": 248.86},{"StationIdentifier": "1650H009","RecordTime": "Nov 28, 2019 1:00:00 AM","WaterLevel": 0.4},{"StationIdentifier": "2420H043","RecordTime": "Nov 28, 2019 1:00:00 AM","WaterLevel": 79.35},{"StationIdentifier": "1630H034","RecordTime": "Nov 28, 2019 12:20:00 AM","WaterLevel": 278.37},{"StationIdentifier": "1580H021","RecordTime": "Nov 28, 2019 1:00:00 AM","WaterLevel": 1.27},{"StationIdentifier": "2420H036","RecordTime": "Nov 28, 2019 1:00:00 AM","WaterLevel": 164.37},{"StationIdentifier": "1730H045","RecordTime": "Nov 28, 2019 1:00:00 AM","WaterLevel": 5.13},{"StationIdentifier": "1510H082","RecordTime": "Nov 28, 2019 1:00:00 AM","WaterLevel": 752.4},{"StationIdentifier": "2370H004","RecordTime": "Nov 28, 2019 1:00:00 AM","WaterLevel": 192.62},{"StationIdentifier": "1630H036","RecordTime": "Nov 28, 2019 1:00:00 AM","WaterLevel": 65.81},{"StationIdentifier": "1550H014","RecordTime": "Nov 28, 2019 1:00:00 AM","WaterLevel": 26.76},{"StationIdentifier": "2420H019","RecordTime": "Nov 28, 2019 1:00:00 AM","WaterLevel": 109.94},{"StationIdentifier": "1550H012","RecordTime": "Nov 28, 2019 1:00:00 AM","WaterLevel": 1.35},{"StationIdentifier": "1430H061","RecordTime": "Nov 28, 2019 1:00:00 AM","WaterLevel": 25},{"StationIdentifier": "1730H066","RecordTime": "Nov 28, 2019 1:00:00 AM","WaterLevel": 138.54},{"StationIdentifier": "2200H025","RecordTime": "Nov 28, 2019 1:00:00 AM","WaterLevel": 206.78},{"StationIdentifier": "1630H032","RecordTime": "Nov 28, 2019 12:20:00 AM","WaterLevel": 0.61},{"StationIdentifier": "1540H039","RecordTime": "Nov 28, 2019 1:00:00 AM","WaterLevel": 38.99},{"StationIdentifier": "1540H030","RecordTime": "Nov 28, 2019 1:00:00 AM","WaterLevel": 27.2},{"StationIdentifier": "2370H025","RecordTime": "Nov 28, 2019 1:00:00 AM","WaterLevel": 261.63},{"StationIdentifier": "1430H056","RecordTime": "Nov 28, 2019 1:00:00 AM","WaterLevel": 79.83},{"StationIdentifier": "1730H061","RecordTime": "Nov 28, 2019 1:00:00 AM","WaterLevel": 266.25},{"StationIdentifier": "1630H023","RecordTime": "Nov 28, 2019 1:00:00 AM","WaterLevel": 0.46},{"StationIdentifier": "1630H024","RecordTime": "Nov 28, 2019 1:00:00 AM","WaterLevel": 69.13},{"StationIdentifier": "2560H006","RecordTime": "Nov 28, 2019 1:00:00 AM","WaterLevel": 3.16},{"StationIdentifier": "2370H018","RecordTime": "Nov 28, 2019 1:00:00 AM","WaterLevel": 124.15},{"StationIdentifier": "1540H037","RecordTime": "Nov 28, 2019 1:00:00 AM","WaterLevel": 32.13},{"StationIdentifier": "1540H009","RecordTime": "Nov 28, 2019 1:00:00 AM","WaterLevel": 2.01},{"StationIdentifier": "2200H011","RecordTime": "Nov 28, 2019 1:00:00 AM","WaterLevel": 25.58},{"StationIdentifier": "1540H032","RecordTime": "Nov 28, 2019 1:00:00 AM","WaterLevel": 20.19},{"StationIdentifier": "1580H018","RecordTime": "Nov 28, 2019 1:00:00 AM","WaterLevel": 21.24},{"StationIdentifier": "1430H054","RecordTime": "Nov 28, 2019 1:00:00 AM","WaterLevel": 48.26},{"StationIdentifier": "1730H069","RecordTime": "Nov 28, 2019 1:00:00 AM","WaterLevel": 141.1},{"StationIdentifier": "1630H028", ...

# %%
import json
json.loads(r.text)
# Out:
# {'@odata.context': 'http://odata.wra.gov.tw/v4/$metadata#RealtimeWaterLevel',
#  '@odata.count': 100,
#  'value': [{'StationIdentifier': '1730H077',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 740.46},
#   {'StationIdentifier': '2560H024',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 202.6},
#   {'StationIdentifier': '1740H002',
#    'RecordTime': 'Nov 28, 2019 12:50:00 AM',
#    'WaterLevel': 4.41},
#   {'StationIdentifier': '1730H074',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 245.47},
#   {'StationIdentifier': '2560H020',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': -0.37},
#   {'StationIdentifier': '1630H040',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 1.78},
#   {'StationIdentifier': '1730H070',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 226.21},
#   {'StationIdentifier': '2560H023',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 13.04},
#   {'StationIdentifier': '1730H072',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 248.86},
#   {'StationIdentifier': '1650H009',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 0.4},
#   {'StationIdentifier': '2420H043',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 79.35},
#   {'StationIdentifier': '1630H034',
#    'RecordTime': 'Nov 28, 2019 12:20:00 AM',
#    'WaterLevel': 278.37},
#   {'StationIdentifier': '1580H021',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 1.27},
#   {'StationIdentifier': '2420H036',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 164.37},
#   {'StationIdentifier': '1730H045',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 5.13},
#   {'StationIdentifier': '1510H082',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 752.4},
#   {'StationIdentifier': '2370H004',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 192.62},
#   {'StationIdentifier': '1630H036',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 65.81},
#   {'StationIdentifier': '1550H014',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 26.76},
#   {'StationIdentifier': '2420H019',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 109.94},
#   {'StationIdentifier': '1550H012',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 1.35},
#   {'StationIdentifier': '1430H061',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 25},
#   {'StationIdentifier': '1730H066',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 138.54},
#   {'StationIdentifier': '2200H025',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 206.78},
#   {'StationIdentifier': '1630H032',
#    'RecordTime': 'Nov 28, 2019 12:20:00 AM',
#    'WaterLevel': 0.61},
#   {'StationIdentifier': '1540H039',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 38.99},
#   {'StationIdentifier': '1540H030',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 27.2},
#   {'StationIdentifier': '2370H025',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 261.63},
#   {'StationIdentifier': '1430H056',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 79.83},
#   {'StationIdentifier': '1730H061',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 266.25},
#   {'StationIdentifier': '1630H023',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 0.46},
#   {'StationIdentifier': '1630H024',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 69.13},
#   {'StationIdentifier': '2560H006',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 3.16},
#   {'StationIdentifier': '2370H018',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 124.15},
#   {'StationIdentifier': '1540H037',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 32.13},
#   {'StationIdentifier': '1540H009',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 2.01},
#   {'StationIdentifier': '2200H011',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 25.58},
#   {'StationIdentifier': '1540H032',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 20.19},
#   {'StationIdentifier': '1580H018',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 21.24},
#   {'StationIdentifier': '1430H054',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 48.26},
#   {'StationIdentifier': '1730H069',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 141.1},
#   {'StationIdentifier': '1630H028',
#    'RecordTime': 'Nov 28, 2019 12:20:00 AM',
#    'WaterLevel': 10.26},
#   {'StationIdentifier': '1630H030',
#    'RecordTime': 'Nov 28, 2019 12:20:00 AM',
#    'WaterLevel': 1.55},
#   {'StationIdentifier': '1430H045',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 91.6},
#   {'StationIdentifier': '1540H033',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 23.32},
#   {'StationIdentifier': '1350H022',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 253.91},
#   {'StationIdentifier': '1590H019',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 14.89},
#   {'StationIdentifier': '1540H029',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 12.77},
#   {'StationIdentifier': '1350H025',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 1.58},
#   {'StationIdentifier': '1430H051',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 95.67},
#   {'StationIdentifier': '1730H036',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 107.42},
#   {'StationIdentifier': '1510H087',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 428.66},
#   {'StationIdentifier': '2200H028',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 278.28},
#   {'StationIdentifier': '1670H003',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 0.26},
#   {'StationIdentifier': '1590H015',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 9.3},
#   {'StationIdentifier': '1630H018',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 10.03},
#   {'StationIdentifier': '1430H040',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 19.45},
#   {'StationIdentifier': '1350H031',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 1.5},
#   {'StationIdentifier': '1350H018',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 282.05},
#   {'StationIdentifier': '1590H012',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 2.83},
#   {'StationIdentifier': '1510H080',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 1068.95},
#   {'StationIdentifier': '1350H023',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 256.28},
#   {'StationIdentifier': '1430H047',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 72.3},
#   {'StationIdentifier': '1510H083',
#    'RecordTime': 'Nov 28, 2019 12:50:00 AM',
#    'WaterLevel': 116.57},
#   {'StationIdentifier': '2200H021',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 369.59},
#   {'StationIdentifier': '1660H011',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 1.48},
#   {'StationIdentifier': '1430H037',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 380.48},
#   {'StationIdentifier': '1310H001',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 13.65},
#   {'StationIdentifier': '1350H029',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 175.93},
#   {'StationIdentifier': '1430H029',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 50.62},
#   {'StationIdentifier': '1300H022',
#    'RecordTime': 'Nov 28, 2019 12:50:00 AM',
#    'WaterLevel': 1.2},
#   {'StationIdentifier': '1850H005',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 22.13},
#   {'StationIdentifier': '2560H017',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 366.42},
#   {'StationIdentifier': '1580H007',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 23.67},
#   {'StationIdentifier': '1430H058',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 83.14},
#   {'StationIdentifier': '2370H019',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 155.97},
#   {'StationIdentifier': '1140H110',
#    'RecordTime': 'Nov 28, 2019 12:50:00 AM',
#    'WaterLevel': 42.56},
#   {'StationIdentifier': '1510H076',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 4.99},
#   {'StationIdentifier': '1740H007',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 0.84},
#   {'StationIdentifier': '1660H010',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 7.46},
#   {'StationIdentifier': '1140H096',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 170.67},
#   {'StationIdentifier': '1350H001',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 169.81},
#   {'StationIdentifier': '1350H027',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 145.82},
#   {'StationIdentifier': '1430H025',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 9.94},
#   {'StationIdentifier': '1290H007',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 12.55},
#   {'StationIdentifier': '1740H011',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 6.62},
#   {'StationIdentifier': '2420H046',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 35.92},
#   {'StationIdentifier': '1420H053',
#    'RecordTime': 'Nov 28, 2019 12:50:00 AM',
#    'WaterLevel': 471.66},
#   {'StationIdentifier': '1340H011',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 7.38},
#   {'StationIdentifier': '1680H004',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 1.11},
#   {'StationIdentifier': '1140H066',
#    'RecordTime': 'Nov 28, 2019 12:50:00 AM',
#    'WaterLevel': 1.97},
#   {'StationIdentifier': '1510H064',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 265.06},
#   {'StationIdentifier': '1630H013',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 15.52},
#   {'StationIdentifier': '1650H014',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 0.96},
#   {'StationIdentifier': '1140H068',
#    'RecordTime': 'Nov 28, 2019 12:50:00 AM',
#    'WaterLevel': 49.04},
#   {'StationIdentifier': '1340H013',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 247.02},
#   {'StationIdentifier': '1350H020',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 220.79},
#   {'StationIdentifier': '1420H056',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 196.48},
#   {'StationIdentifier': '1280H001',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 71.47},
#   {'StationIdentifier': '1740H009',
#    'RecordTime': 'Nov 28, 2019 1:00:00 AM',
#    'WaterLevel': 32.27}],
#  '@odata.nextLink': 'http://odata.wra.gov.tw/v4/RealtimeWaterLevel?$skip=100&$top=100'}

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
import requests
import json
import pandas as pd

# %%
r = requests.get('http://odata.wra.gov.tw/v4/RealtimeWaterLevel')

# %%
water = json.loads(r.text)['value']

# %%
water
# Out:
# [{'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '2560H023',
#   'WaterLevel': 13.01},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '2560H020',
#   'WaterLevel': 0.14},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '2370H017',
#   'WaterLevel': 58.48},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1730H057',
#   'WaterLevel': 43.46},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '2500H003',
#   'WaterLevel': 32.08},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1590H016',
#   'WaterLevel': 11.24},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '2200H029',
#   'WaterLevel': 145.15},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1660H009',
#   'WaterLevel': 4.82},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1630H024',
#   'WaterLevel': 69.11},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1580H022',
#   'WaterLevel': 1.16},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1650H013',
#   'WaterLevel': 5.69},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1850H004',
#   'WaterLevel': 72.1},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1430H037',
#   'WaterLevel': 380.47},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1430H054',
#   'WaterLevel': 48.33},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1670H004',
#   'WaterLevel': 2.97},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1540H032',
#   'WaterLevel': 20.22},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1740H008',
#   'WaterLevel': 1.12},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1430H030',
#   'WaterLevel': 87.54},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '2370H019',
#   'WaterLevel': 156.01},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1430H051',
#   'WaterLevel': 95.67},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1660H012',
#   'WaterLevel': 0.29},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1580H021',
#   'WaterLevel': 1.27},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1540H029',
#   'WaterLevel': 12.78},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '2200H007',
#   'WaterLevel': 155.95},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1430H028',
#   'WaterLevel': 23.57},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '2370H004',
#   'WaterLevel': 192.58},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1430H047',
#   'WaterLevel': 72.38},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1650H015',
#   'WaterLevel': 0.28},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1580H017',
#   'WaterLevel': 25.73},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1510H084',
#   'WaterLevel': 145.01},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1730H068',
#   'WaterLevel': 10.13},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '2200H026',
#   'WaterLevel': 106.72},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1420H057',
#   'WaterLevel': 639.36},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1420H058',
#   'WaterLevel': 440.48},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1630H040',
#   'WaterLevel': 1.93},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1580H001',
#   'WaterLevel': 224.2},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1510H080',
#   'WaterLevel': 1068.94},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1730H043',
#   'WaterLevel': 23.07},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1510H079',
#   'WaterLevel': 187.7},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1400H018',
#   'WaterLevel': 55.22},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1420H055',
#   'WaterLevel': 318.56},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1510H082',
#   'WaterLevel': 752.39},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1400H009',
#   'WaterLevel': 191.54},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '2200H025',
#   'WaterLevel': 207.14},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1680H005',
#   'WaterLevel': 0.04},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1510H071',
#   'WaterLevel': 20.61},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '2200H020',
#   'WaterLevel': 318.17},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1550H012',
#   'WaterLevel': 0.76},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1510H058',
#   'WaterLevel': 12.2},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1540H030',
#   'WaterLevel': 27.19},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1550H014',
#   'WaterLevel': 26.77},
#  {'RecordTime': 'Nov 30, 2019 2:00:00 PM',
#   'StationIdentifier': '1140H110',
#   'WaterLevel': 42.56},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1430H058',
#   'WaterLevel': 82.99},
#  {'RecordTime': 'Nov 30, 2019 2:00:00 PM',
#   'StationIdentifier': '1140H096',
#   'WaterLevel': 170.72},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1630H005',
#   'WaterLevel': 39.77},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1510H049',
#   'WaterLevel': 470.81},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1540H009',
#   'WaterLevel': 1.63},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1540H039',
#   'WaterLevel': 38.99},
#  {'RecordTime': 'Nov 30, 2019 2:00:00 PM',
#   'StationIdentifier': '1140H066',
#   'WaterLevel': 1.98},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1340H011',
#   'WaterLevel': 7.34},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1540H037',
#   'WaterLevel': 32},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1590H013',
#   'WaterLevel': 20.75},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1430H056',
#   'WaterLevel': 79.82},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1520H008',
#   'WaterLevel': 78.22},
#  {'RecordTime': 'Nov 30, 2019 2:00:00 PM',
#   'StationIdentifier': '1140H068',
#   'WaterLevel': 49.06},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '2560H024',
#   'WaterLevel': 202.63},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1300H023',
#   'WaterLevel': 52.21},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1540H033',
#   'WaterLevel': 23.28},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1580H018',
#   'WaterLevel': 21.23},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1430H045',
#   'WaterLevel': 91.6},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1510H086',
#   'WaterLevel': 318},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '2420H036',
#   'WaterLevel': 164.36},
#  {'RecordTime': 'Nov 30, 2019 2:00:00 PM',
#   'StationIdentifier': '2560H017',
#   'WaterLevel': 366.4},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1300H020',
#   'WaterLevel': 251.43},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1350H031',
#   'WaterLevel': 1.96},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1580H008',
#   'WaterLevel': 19.42},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1430H040',
#   'WaterLevel': 19.43},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1510H075',
#   'WaterLevel': 346.45},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '2420H019',
#   'WaterLevel': 109.95},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1650H012',
#   'WaterLevel': 0.71},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1300H019',
#   'WaterLevel': -999998},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1350H029',
#   'WaterLevel': 175.96},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1550H017',
#   'WaterLevel': 15.7},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1310H001',
#   'WaterLevel': 13.65},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1350H022',
#   'WaterLevel': 253.9},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1650H009',
#   'WaterLevel': 0.39},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '2370H025',
#   'WaterLevel': 261.62},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1140H129',
#   'WaterLevel': 27.11},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1350H027',
#   'WaterLevel': 145.83},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1420H054',
#   'WaterLevel': 704.2},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1300H022',
#   'WaterLevel': 1.52},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1350H018',
#   'WaterLevel': 282.05},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1630H036',
#   'WaterLevel': 65.8},
#  {'RecordTime': 'Nov 30, 2019 10:50:00 AM',
#   'StationIdentifier': '1630H030',
#   'WaterLevel': 1.55},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1350H001',
#   'WaterLevel': 169.79},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1350H020',
#   'WaterLevel': 220.77},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1420H049',
#   'WaterLevel': 54.1},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1290H007',
#   'WaterLevel': 12.56},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1350H016',
#   'WaterLevel': 98.31},
#  {'RecordTime': 'Nov 30, 2019 2:10:00 PM',
#   'StationIdentifier': '1280H001',
#   'WaterLevel': 71.48}]

# %%
pd.DataFrame(water)
# Out:
#                  RecordTime StationIdentifier  WaterLevel
# 0   Nov 30, 2019 2:10:00 PM          2560H023       13.01
# 1   Nov 30, 2019 2:10:00 PM          2560H020        0.14
# 2   Nov 30, 2019 2:10:00 PM          2370H017       58.48
# 3   Nov 30, 2019 2:10:00 PM          1730H057       43.46
# 4   Nov 30, 2019 2:10:00 PM          2500H003       32.08
# ..                      ...               ...         ...
# 95  Nov 30, 2019 2:10:00 PM          1350H020      220.77
# 96  Nov 30, 2019 2:10:00 PM          1420H049       54.10
# 97  Nov 30, 2019 2:10:00 PM          1290H007       12.56
# 98  Nov 30, 2019 2:10:00 PM          1350H016       98.31
# 99  Nov 30, 2019 2:10:00 PM          1280H001       71.48
#
# [100 rows x 3 columns]
