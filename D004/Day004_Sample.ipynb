# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 下載檔案

# %%
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"11005454781","type":"PushEvent","actor":{"id":8441471,"login":"encelo","display_login":"encelo","gravatar_id":"","url":"https://api.github.com/users/encelo","avatar_url":"https://avatars.githubusercontent.com/u/8441471?"},"repo":{"id":188892444,"name":"nCine/nCine-artifacts","url":"https://api.github.com/repos/nCine/nCine-artifacts"},"payload":{"push_id":4351951871,"size":1,"distinct_size":1,"ref":"refs/heads/nCine-develop-linux-gcc","head":"fbccbee91bdd22dae140a30f6e31c9d0bc089bc4","before":"0aea5b88b4047d55cf659cb0ad3cdee41c92756d","commits":[{"sha":"fbccbee91bdd22dae140a30f6e31c9d0bc089bc4","author":{"email":"pipelines@azure.com","name":"Azure Pipelines"},"message":"Push artifact from Azure Pipelines build 20191204.1 with id 549\\n- nCine artifact from branch \'develop\' with commit id 568c6d737d085b7510fbf7368f753a9376c07bd9","distinct":true,"url":"https://api.github.com/repos/nCine/nCine-artifacts/commits/fbccbee91bdd22dae140a30f6e31c9d0bc089bc4"}]},"public":true,"created_at":"2019-12-04T01:56:06Z","org":{"id":20152386,"login":"nCine","gravatar_id":"","url":"https://api.github.com/orgs/nCine","avatar_url":"https://avatars.githubusercontent.com/u/20152386?"}},{"id":"11005454767","type":"CreateEvent","actor":{"id":1281508,"login":"mizt","display_login":"mizt","gravatar_id":"","url":"https://api.github.com/users/mizt","avatar_url":"https://avatars.githubusercontent.com/u/1281508?"},"repo":{"id":225756037,"name":"mizt/stripes","url":"https://api.github.com/repos/mizt/stripes"},"payload":{"ref":null,"ref_type":"repository","master_branch":"master","description":null,"pusher_type":"user"},"public":true,"created_at":"2019-12-04T01:56:06Z"},{"id":"11005454762","type":"PullRequestEvent","actor":{"id":49699333,"login":"dependabot[bot]","display_login":"dependabot","gravatar_id":"","url":"https://api.github.com/users/dependabot[bot]","avatar_url":"https://avatars.githubusercontent.com/u/49699333?"},"repo":{"id":225682013,"name":"laasyakanuru/todoapp","url":"https://api.github.com/repos/laasyakanuru/todoapp"},"payload":{"action":"opened","number":1,"pull_request":{"url":"https://api.github.com/repos/laasyakanuru/todoapp/pulls/1","id":348652525,"node_id":"MDExOlB1bGxSZXF1ZXN0MzQ4NjUyNTI1","html_url":"https://github.com/laasyakanuru/todoapp/pull/1","diff_url":"https://github.com/laasyakanuru/todoapp/pull/1.diff","patch_url":"https://github.com/laasyakanuru/todoapp/pull/1.patch","issue_url":"https://api.github.com/repos/laasyakanuru/todoapp/issues/1","number":1,"state":"open","locked":false,"title":"Bump werkzeug from 0.11.15 to 0.15.3","user":{"login":"dependabot[bot]","id":49699333,"node_id":"MDM6Qm90NDk2OTkzMzM=","avatar_url":"https://avatars0.githubusercontent.com/in/29110?v=4","gravatar_id":"","url":"https://api.github.com/users/dependabot%5Bbot%5D","html_url":"https://github.com/apps/dependabot","followers_url":"https://api.github.com/users/dependabot%5Bbot%5D/followers","following_url":"https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}","gists_url":"https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}","starred_url":"https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/dependabot%5Bbot%5D/subscriptions","organizations_url":"https://api.github.com/users/dependabot%5Bbot%5D/orgs","repos_url":"https://api.github.com/users/dependabot%5Bbot%5D/repos","events_url":"https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}","received_events_url":"https://api.github.com/users/dependabot%5Bbot%5D/received_events","type":"Bot","site_admin":false},"body":"Bumps [werkzeug](https://github.com/pallets/werkzeug) from 0.11.15 to 0.15.3.\\n<details>\\n<summary>Release notes</summary>\\n\\n*Sourced from [werkzeug\'s releases](https://github.com/pallets/werkzeug/releases).*\\n\\n> ## 0.15.3\\n> * Blog: https://palletsprojects.com/blog/werkzeug-0-15-3-released/\\r\\n> * Changes: https://werkzeug.palletsprojects.com/en/0.15.x/chang ...

# %%
import json

json.loads(r.text)
# Out:
# [{'id': '11005454781',
#   'type': 'PushEvent',
#   'actor': {'id': 8441471,
#    'login': 'encelo',
#    'display_login': 'encelo',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/encelo',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8441471?'},
#   'repo': {'id': 188892444,
#    'name': 'nCine/nCine-artifacts',
#    'url': 'https://api.github.com/repos/nCine/nCine-artifacts'},
#   'payload': {'push_id': 4351951871,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/nCine-develop-linux-gcc',
#    'head': 'fbccbee91bdd22dae140a30f6e31c9d0bc089bc4',
#    'before': '0aea5b88b4047d55cf659cb0ad3cdee41c92756d',
#    'commits': [{'sha': 'fbccbee91bdd22dae140a30f6e31c9d0bc089bc4',
#      'author': {'email': 'pipelines@azure.com', 'name': 'Azure Pipelines'},
#      'message': "Push artifact from Azure Pipelines build 20191204.1 with id 549\n- nCine artifact from branch 'develop' with commit id 568c6d737d085b7510fbf7368f753a9376c07bd9",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/nCine/nCine-artifacts/commits/fbccbee91bdd22dae140a30f6e31c9d0bc089bc4'}]},
#   'public': True,
#   'created_at': '2019-12-04T01:56:06Z',
#   'org': {'id': 20152386,
#    'login': 'nCine',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/nCine',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/20152386?'}},
#  {'id': '11005454767',
#   'type': 'CreateEvent',
#   'actor': {'id': 1281508,
#    'login': 'mizt',
#    'display_login': 'mizt',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mizt',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1281508?'},
#   'repo': {'id': 225756037,
#    'name': 'mizt/stripes',
#    'url': 'https://api.github.com/repos/mizt/stripes'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-04T01:56:06Z'},
#  {'id': '11005454762',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 225682013,
#    'name': 'laasyakanuru/todoapp',
#    'url': 'https://api.github.com/repos/laasyakanuru/todoapp'},
#   'payload': {'action': 'opened',
#    'number': 1,
#    'pull_request': {'url': 'https://api.github.com/repos/laasyakanuru/todoapp/pulls/1',
#     'id': 348652525,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzQ4NjUyNTI1',
#     'html_url': 'https://github.com/laasyakanuru/todoapp/pull/1',
#     'diff_url': 'https://github.com/laasyakanuru/todoapp/pull/1.diff',
#     'patch_url': 'https://github.com/laasyakanuru/todoapp/pull/1.patch',
#     'issue_url': 'https://api.github.com/repos/laasyakanuru/todoapp/issues/1',
#     'number': 1,
#     'state': 'open',
#     'locked': False,
#     'title': 'Bump werkzeug from 0.11.15 to 0.15.3',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': 'Bumps [werkzeug](https://github.com/pallets/werkzeug) from 0.11.15 to 0.15.3.\n<details>\n<summary>Release notes</summary>\n\n*Sourced from [werkzeug\'s releases](https://github.com/pallets/werkzeug/releases).*\n\n> ## 0.15.3\n> * Blog: https://palletsprojects.com/blog/werkzeug-0-15-3-released/\r\n> * Changes: https://werkzeug.palletsprojects.com/en/0.15.x/changes/#version-0-15-3\r\n> \r\n> \n> ## 0.15.2\n> * Blog: https://palletsprojects.com/blog/werkzeug-0-15-2-released/\r\n> * Changes: https://werkzeug.palletsprojects.com/en/0.15.x/changes/#version-0-15-2\n> \n> ## 0.15.1\n> * Blog: https://palletsprojects.com/blog/werkzeug-0-15-1-released/\r\n> * Changes: https://werkzeug.palletsprojects.com/en/0.15.x/changes/\n> \n> ## 0.15.0\n> * Blog: https://palletsprojects.com/blog/werkzeug-0-15-0-released/\r\n> * Changes: https://werkzeug.palletsprojects.com/en/0.15.x/changes/\n> \n> ## 0.13\n> [Read the announcement here.](https://www.palletsprojects.com/blog/werkzeug-013-released/)\r\n> \r\n> [Read the full changelog.](http://werkzeug.pocoo.org/docs/latest/changes/#version-0-13)\r\n> \r\n> Install from [PyPI](https://pypi.org/Werkzeug/0.13) with pip:\r\n> \r\n> ```\r\n> pip install -U Werkzeug\r\n> ```\r\n> \r\n</details>\n<details>\n<summary>Changelog</summary>\n\n*Sourced from [werkzeug\'s changelog](https://github.com/pallets/werkzeug/blob/master/CHANGES.rst).*\n\n> Version 0.15.3\n> --------------\n> \n> Released 2019-05-14\n> \n> -   Properly handle multi-line header folding in development server in\n>     Python 2.7. (:issue:`1080`)\n> -   Restore the ``response`` argument to :exc:`~exceptions.Unauthorized`.\n>     (:pr:`1527`)\n> -   :exc:`~exceptions.Unauthorized` doesn\'t add the ``WWW-Authenticate``\n>     header if ``www_authenticate`` is not given. (:issue:`1516`)\n> -   The default URL converter correctly encodes bytes to string rather\n>     than representing them with ``b\'\'``. (:issue:`1502`)\n> -   Fix the filename format string in\n>     :class:`~middleware.profiler.ProfilerMiddleware` to correctly handle\n>     float values. (:issue:`1511`)\n> -   Update :class:`~middleware.lint.LintMiddleware` to work on Python 3.\n>     (:issue:`1510`)\n> -   The debugger detects cycles in chained exceptions and does not time\n>     out in that case. (:issue:`1536`)\n> -   When running the development server in Docker, the debugger security\n>     pin is now unique per container.\n> \n> \n> Version 0.15.2\n> --------------\n> \n> Released 2019-04-02\n> \n> -   ``Rule`` code generation uses a filename that coverage will ignore.\n>     The previous value, "generated", was causing coverage to fail.\n>     (:issue:`1487`)\n> -   The test client removes the cookie header if there are no persisted\n>     cookies. This fixes an issue introduced in 0.15.0 where the cookies\n>     from the original request were used for redirects, causing functions\n>     such as logout to fail. (:issue:`1491`)\n> -   The test client copies the environ before passing it to the app, to\n>     prevent in-place modifications from affecting redirect requests.\n>     (:issue:`1498`)\n> -   The ``"werkzeug"`` logger only adds a handler if there is no handler\n>     configured for its level in the logging chain. This avoids double\n>     logging if other code configures logging first. (:issue:`1492`)\n> \n> \n> Version 0.15.1\n> --------------\n> \n> Released 2019-03-21\n> \n> -   :exc:`~exceptions.Unauthorized` takes ``description`` as the first\n></tr></table> ... (truncated)\n</details>\n<details>\n<summary>Commits</summary>\n\n- [`9b1123a`](https://github.com/pallets/werkzeug/commit/9b1123a779e95b5c38ca911ce1329e87a3348a92) release version 0.15.3\n- [`00bc43b`](https://github.com/pallets/werkzeug/commit/00bc43b1672e662e5e3b8cecd79e67fc968fa246) unique debugger pin in Docker containers\n- [`2cbdf2b`](https://github.com/pallets/werkzeug/commit/2cbdf2b02273daccf85845b1e1569096e65ffe58) Merge pull request [#1542](https://github-redirect.dependabo ...
#     'created_at': '2019-12-04T01:56:05Z',
#     'updated_at': '2019-12-04T01:56:05Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/laasyakanuru/todoapp/pulls/1/commits',
#     'review_comments_url': 'https://api.github.com/repos/laasyakanuru/todoapp/pulls/1/comments',
#     'review_comment_url': 'https://api.github.com/repos/laasyakanuru/todoapp/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/laasyakanuru/todoapp/issues/1/comments',
#     'statuses_url': 'https://api.github.com/repos/laasyakanuru/todoapp/statuses/7ebd5c7731ffb53a62332653db4531313a4f18f0',
#     'head': {'label': 'laasyakanuru:dependabot/pip/werkzeug-0.15.3',
#      'ref': 'dependabot/pip/werkzeug-0.15.3',
#      'sha': '7ebd5c7731ffb53a62332653db4531313a4f18f0',
#      'user': {'login': 'laasyakanuru',
#       'id': 45540452,
#       'node_id': 'MDQ6VXNlcjQ1NTQwNDUy',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/45540452?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/laasyakanuru',
#       'html_url': 'https://github.com/laasyakanuru',
#       'followers_url': 'https://api.github.com/users/laasyakanuru/followers',
#       'following_url': 'https://api.github.com/users/laasyakanuru/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/laasyakanuru/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/laasyakanuru/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/laasyakanuru/subscriptions',
#       'organizations_url': 'https://api.github.com/users/laasyakanuru/orgs',
#       'repos_url': 'https://api.github.com/users/laasyakanuru/repos',
#       'events_url': 'https://api.github.com/users/laasyakanuru/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/laasyakanuru/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 225682013,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMjU2ODIwMTM=',
#       'name': 'todoapp',
#       'full_name': 'laasyakanuru/todoapp',
#       'private': False,
#       'owner': {'login': 'laasyakanuru',
#        'id': 45540452,
#        'node_id': 'MDQ6VXNlcjQ1NTQwNDUy',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/45540452?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/laasyakanuru',
#        'html_url': 'https://github.com/laasyakanuru',
#        'followers_url': 'https://api.github.com/users/laasyakanuru/followers',
#        'following_url': 'https://api.github.com/users/laasyakanuru/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/laasyakanuru/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/laasyakanuru/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/laasyakanuru/subscriptions',
#        'organizations_url': 'https://api.github.com/users/laasyakanuru/orgs',
#        'repos_url': 'https://api.github.com/users/laasyakanuru/repos',
#        'events_url': 'https://api.github.com/users/laasyakanuru/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/laasyakanuru/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/laasyakanuru/todoapp',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/laasyakanuru/todoapp',
#       'forks_url': 'https://api.github.com/repos/laasyakanuru/todoapp/forks',
#       'keys_url': 'https://api.github.com/repos/laasyakanuru/todoapp/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/laasyakanuru/todoapp/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/laasyakanuru/todoapp/teams',
#       'hooks_url': 'https://api.github.com/repos/laasyakanuru/todoapp/hooks',
#       'issue_events_url': 'https://api.github.com/repos/laasyakanuru/todoapp/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/laasyakanuru/todoapp/events',
#       'assignees_url': 'https://api.github.com/repos/laasyakanuru/todoapp/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/laasyakanuru/todoapp/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/laasyakanuru/todoapp/tags',
#       'blobs_url': 'https://api.github.com/repos/laasyakanuru/todoapp/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/laasyakanuru/todoapp/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/laasyakanuru/todoapp/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/laasyakanuru/todoapp/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/laasyakanuru/todoapp/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/laasyakanuru/todoapp/languages',
#       'stargazers_url': 'https://api.github.com/repos/laasyakanuru/todoapp/stargazers',
#       'contributors_url': 'https://api.github.com/repos/laasyakanuru/todoapp/contributors',
#       'subscribers_url': 'https://api.github.com/repos/laasyakanuru/todoapp/subscribers',
#       'subscription_url': 'https://api.github.com/repos/laasyakanuru/todoapp/subscription',
#       'commits_url': 'https://api.github.com/repos/laasyakanuru/todoapp/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/laasyakanuru/todoapp/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/laasyakanuru/todoapp/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/laasyakanuru/todoapp/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/laasyakanuru/todoapp/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/laasyakanuru/todoapp/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/laasyakanuru/todoapp/merges',
#       'archive_url': 'https://api.github.com/repos/laasyakanuru/todoapp/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/laasyakanuru/todoapp/downloads',
#       'issues_url': 'https://api.github.com/repos/laasyakanuru/todoapp/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/laasyakanuru/todoapp/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/laasyakanuru/todoapp/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/laasyakanuru/todoapp/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/laasyakanuru/todoapp/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/laasyakanuru/todoapp/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/laasyakanuru/todoapp/deployments',
#       'created_at': '2019-12-03T17:50:05Z',
#       'updated_at': '2019-12-03T18:29:29Z',
#       'pushed_at': '2019-12-04T01:56:05Z',
#       'git_url': 'git://github.com/laasyakanuru/todoapp.git',
#       'ssh_url': 'git@github.com:laasyakanuru/todoapp.git',
#       'clone_url': 'https://github.com/laasyakanuru/todoapp.git',
#       'svn_url': 'https://github.com/laasyakanuru/todoapp',
#       'homepage': None,
#       'size': 27,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'CSS',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'laasyakanuru:master',
#      'ref': 'master',
#      'sha': '1e65e9513d0eaf27ec3c657e3ec2348cb85a9139',
#      'user': {'login': 'laasyakanuru',
#       'id': 45540452,
#       'node_id': 'MDQ6VXNlcjQ1NTQwNDUy',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/45540452?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/laasyakanuru',
#       'html_url': 'https://github.com/laasyakanuru',
#       'followers_url': 'https://api.github.com/users/laasyakanuru/followers',
#       'following_url': 'https://api.github.com/users/laasyakanuru/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/laasyakanuru/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/laasyakanuru/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/laasyakanuru/subscriptions',
#       'organizations_url': 'https://api.github.com/users/laasyakanuru/orgs',
#       'repos_url': 'https://api.github.com/users/laasyakanuru/repos',
#       'events_url': 'https://api.github.com/users/laasyakanuru/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/laasyakanuru/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 225682013,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMjU2ODIwMTM=',
#       'name': 'todoapp',
#       'full_name': 'laasyakanuru/todoapp',
#       'private': False,
#       'owner': {'login': 'laasyakanuru',
#        'id': 45540452,
#        'node_id': 'MDQ6VXNlcjQ1NTQwNDUy',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/45540452?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/laasyakanuru',
#        'html_url': 'https://github.com/laasyakanuru',
#        'followers_url': 'https://api.github.com/users/laasyakanuru/followers',
#        'following_url': 'https://api.github.com/users/laasyakanuru/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/laasyakanuru/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/laasyakanuru/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/laasyakanuru/subscriptions',
#        'organizations_url': 'https://api.github.com/users/laasyakanuru/orgs',
#        'repos_url': 'https://api.github.com/users/laasyakanuru/repos',
#        'events_url': 'https://api.github.com/users/laasyakanuru/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/laasyakanuru/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/laasyakanuru/todoapp',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/laasyakanuru/todoapp',
#       'forks_url': 'https://api.github.com/repos/laasyakanuru/todoapp/forks',
#       'keys_url': 'https://api.github.com/repos/laasyakanuru/todoapp/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/laasyakanuru/todoapp/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/laasyakanuru/todoapp/teams',
#       'hooks_url': 'https://api.github.com/repos/laasyakanuru/todoapp/hooks',
#       'issue_events_url': 'https://api.github.com/repos/laasyakanuru/todoapp/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/laasyakanuru/todoapp/events',
#       'assignees_url': 'https://api.github.com/repos/laasyakanuru/todoapp/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/laasyakanuru/todoapp/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/laasyakanuru/todoapp/tags',
#       'blobs_url': 'https://api.github.com/repos/laasyakanuru/todoapp/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/laasyakanuru/todoapp/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/laasyakanuru/todoapp/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/laasyakanuru/todoapp/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/laasyakanuru/todoapp/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/laasyakanuru/todoapp/languages',
#       'stargazers_url': 'https://api.github.com/repos/laasyakanuru/todoapp/stargazers',
#       'contributors_url': 'https://api.github.com/repos/laasyakanuru/todoapp/contributors',
#       'subscribers_url': 'https://api.github.com/repos/laasyakanuru/todoapp/subscribers',
#       'subscription_url': 'https://api.github.com/repos/laasyakanuru/todoapp/subscription',
#       'commits_url': 'https://api.github.com/repos/laasyakanuru/todoapp/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/laasyakanuru/todoapp/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/laasyakanuru/todoapp/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/laasyakanuru/todoapp/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/laasyakanuru/todoapp/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/laasyakanuru/todoapp/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/laasyakanuru/todoapp/merges',
#       'archive_url': 'https://api.github.com/repos/laasyakanuru/todoapp/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/laasyakanuru/todoapp/downloads',
#       'issues_url': 'https://api.github.com/repos/laasyakanuru/todoapp/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/laasyakanuru/todoapp/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/laasyakanuru/todoapp/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/laasyakanuru/todoapp/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/laasyakanuru/todoapp/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/laasyakanuru/todoapp/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/laasyakanuru/todoapp/deployments',
#       'created_at': '2019-12-03T17:50:05Z',
#       'updated_at': '2019-12-03T18:29:29Z',
#       'pushed_at': '2019-12-04T01:56:05Z',
#       'git_url': 'git://github.com/laasyakanuru/todoapp.git',
#       'ssh_url': 'git@github.com:laasyakanuru/todoapp.git',
#       'clone_url': 'https://github.com/laasyakanuru/todoapp.git',
#       'svn_url': 'https://github.com/laasyakanuru/todoapp',
#       'homepage': None,
#       'size': 27,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'CSS',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/laasyakanuru/todoapp/pulls/1'},
#      'html': {'href': 'https://github.com/laasyakanuru/todoapp/pull/1'},
#      'issue': {'href': 'https://api.github.com/repos/laasyakanuru/todoapp/issues/1'},
#      'comments': {'href': 'https://api.github.com/repos/laasyakanuru/todoapp/issues/1/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/laasyakanuru/todoapp/pulls/1/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/laasyakanuru/todoapp/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/laasyakanuru/todoapp/pulls/1/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/laasyakanuru/todoapp/statuses/7ebd5c7731ffb53a62332653db4531313a4f18f0'}},
#     'author_association': 'NONE',
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 1,
#     'deletions': 1,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2019-12-04T01:56:06Z'},
#  {'id': '11005454764',
#   'type': 'WatchEvent',
#   'actor': {'id': 6918234,
#    'login': 'farizikhwantri',
#    'display_login': 'farizikhwantri',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/farizikhwantri',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6918234?'},
#   'repo': {'id': 210780812,
#    'name': 'toiaydcdyywlhzvlob/backpack',
#    'url': 'https://api.github.com/repos/toiaydcdyywlhzvlob/backpack'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2019-12-04T01:56:06Z'},
#  {'id': '11005454761',
#   'type': 'CreateEvent',
#   'actor': {'id': 58495810,
#    'login': 'ajdelrocco',
#    'display_login': 'ajdelrocco',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ajdelrocco',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58495810?'},
#   'repo': {'id': 225756030,
#    'name': 'ajdelrocco/helloworld',
#    'url': 'https://api.github.com/repos/ajdelrocco/helloworld'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-04T01:56:06Z'},
#  {'id': '11005454758',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 215538849,
#    'name': 'reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma',
#    'url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma'},
#   'payload': {'action': 'opened',
#    'number': 1,
#    'pull_request': {'url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/pulls/1',
#     'id': 348652523,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzQ4NjUyNTIz',
#     'html_url': 'https://github.com/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/pull/1',
#     'diff_url': 'https://github.com/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/pull/1.diff',
#     'patch_url': 'https://github.com/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/pull/1.patch',
#     'issue_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/issues/1',
#     'number': 1,
#     'state': 'open',
#     'locked': False,
#     'title': 'Bump jackson-databind from 2.9.8 to 2.9.10.1 in /springrest',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': "Bumps [jackson-databind](https://github.com/FasterXML/jackson) from 2.9.8 to 2.9.10.1.\n<details>\n<summary>Commits</summary>\n\n- See full diff in [compare view](https://github.com/FasterXML/jackson/commits)\n</details>\n<br />\n\n[![Dependabot compatibility score](https://dependabot-badges.githubapp.com/badges/compatibility_score?dependency-name=com.fasterxml.jackson.core:jackson-databind&package-manager=maven&previous-version=2.9.8&new-version=2.9.10.1)](https://help.github.com/articles/configuring-automated-security-fixes)\n\nDependabot will resolve any conflicts with this PR as long as you don't alter it yourself. You can also trigger a rebase manually by commenting `@dependabot rebase`.\n\n[//]: # (dependabot-automerge-start)\n[//]: # (dependabot-automerge-end)\n\n---\n\n<details>\n<summary>Dependabot commands and options</summary>\n<br />\n\nYou can trigger Dependabot actions by commenting on this PR:\n- `@dependabot rebase` will rebase this PR\n- `@dependabot recreate` will recreate this PR, overwriting any edits that have been made to it\n- `@dependabot merge` will merge this PR after your CI passes on it\n- `@dependabot squash and merge` will squash and merge this PR after your CI passes on it\n- `@dependabot cancel merge` will cancel a previously requested merge and block automerging\n- `@dependabot reopen` will reopen this PR if it is closed\n- `@dependabot ignore this [patch|minor|major] version` will close this PR and stop Dependabot creating any more for this minor/major version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this dependency` will close this PR and stop Dependabot creating any more for this dependency (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot use these labels` will set the current labels as the default for future PRs for this repo and language\n- `@dependabot use these reviewers` will set the current reviewers as the default for future PRs for this repo and language\n- `@dependabot use these assignees` will set the current assignees as the default for future PRs for this repo and language\n- `@dependabot use this milestone` will set the current milestone as the default for future PRs for this repo and language\n\nYou can disable automated security fix PRs for this repo from the [Security Alerts page](https://github.com/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/network/alerts).\n\n</details>",
#     'created_at': '2019-12-04T01:56:05Z',
#     'updated_at': '2019-12-04T01:56:05Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/pulls/1/commits',
#     'review_comments_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/pulls/1/comments',
#     'review_comment_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/issues/1/comments',
#     'statuses_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/statuses/02b68566725f2de03f2ff983092775e7a99323f0',
#     'head': {'label': 'reshuvishwa1705:dependabot/maven/springrest/com.fasterxml.jackson.core-jackson-databind-2.9.10.1',
#      'ref': 'dependabot/maven/springrest/com.fasterxml.jackson.core-jackson-databind-2.9.10.1',
#      'sha': '02b68566725f2de03f2ff983092775e7a99323f0',
#      'user': {'login': 'reshuvishwa1705',
#       'id': 56624115,
#       'node_id': 'MDQ6VXNlcjU2NjI0MTE1',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/56624115?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/reshuvishwa1705',
#       'html_url': 'https://github.com/reshuvishwa1705',
#       'followers_url': 'https://api.github.com/users/reshuvishwa1705/followers',
#       'following_url': 'https://api.github.com/users/reshuvishwa1705/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/reshuvishwa1705/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/reshuvishwa1705/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/reshuvishwa1705/subscriptions',
#       'organizations_url': 'https://api.github.com/users/reshuvishwa1705/orgs',
#       'repos_url': 'https://api.github.com/users/reshuvishwa1705/repos',
#       'events_url': 'https://api.github.com/users/reshuvishwa1705/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/reshuvishwa1705/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 215538849,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMTU1Mzg4NDk=',
#       'name': 'USTGlobal-16Sep19-Reshu-Vishwakarma',
#       'full_name': 'reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma',
#       'private': False,
#       'owner': {'login': 'reshuvishwa1705',
#        'id': 56624115,
#        'node_id': 'MDQ6VXNlcjU2NjI0MTE1',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/56624115?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/reshuvishwa1705',
#        'html_url': 'https://github.com/reshuvishwa1705',
#        'followers_url': 'https://api.github.com/users/reshuvishwa1705/followers',
#        'following_url': 'https://api.github.com/users/reshuvishwa1705/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/reshuvishwa1705/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/reshuvishwa1705/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/reshuvishwa1705/subscriptions',
#        'organizations_url': 'https://api.github.com/users/reshuvishwa1705/orgs',
#        'repos_url': 'https://api.github.com/users/reshuvishwa1705/repos',
#        'events_url': 'https://api.github.com/users/reshuvishwa1705/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/reshuvishwa1705/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma',
#       'forks_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/forks',
#       'keys_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/teams',
#       'hooks_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/hooks',
#       'issue_events_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/events',
#       'assignees_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/tags',
#       'blobs_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/languages',
#       'stargazers_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/stargazers',
#       'contributors_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/contributors',
#       'subscribers_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/subscribers',
#       'subscription_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/subscription',
#       'commits_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/merges',
#       'archive_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/downloads',
#       'issues_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/deployments',
#       'created_at': '2019-10-16T12:08:02Z',
#       'updated_at': '2019-12-03T18:31:46Z',
#       'pushed_at': '2019-12-04T01:56:05Z',
#       'git_url': 'git://github.com/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma.git',
#       'ssh_url': 'git@github.com:reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma.git',
#       'clone_url': 'https://github.com/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma.git',
#       'svn_url': 'https://github.com/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma',
#       'homepage': None,
#       'size': 293750,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'HTML',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'reshuvishwa1705:master',
#      'ref': 'master',
#      'sha': '52aa3499330089e4ce41a948839299025bfcb81b',
#      'user': {'login': 'reshuvishwa1705',
#       'id': 56624115,
#       'node_id': 'MDQ6VXNlcjU2NjI0MTE1',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/56624115?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/reshuvishwa1705',
#       'html_url': 'https://github.com/reshuvishwa1705',
#       'followers_url': 'https://api.github.com/users/reshuvishwa1705/followers',
#       'following_url': 'https://api.github.com/users/reshuvishwa1705/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/reshuvishwa1705/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/reshuvishwa1705/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/reshuvishwa1705/subscriptions',
#       'organizations_url': 'https://api.github.com/users/reshuvishwa1705/orgs',
#       'repos_url': 'https://api.github.com/users/reshuvishwa1705/repos',
#       'events_url': 'https://api.github.com/users/reshuvishwa1705/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/reshuvishwa1705/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 215538849,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMTU1Mzg4NDk=',
#       'name': 'USTGlobal-16Sep19-Reshu-Vishwakarma',
#       'full_name': 'reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma',
#       'private': False,
#       'owner': {'login': 'reshuvishwa1705',
#        'id': 56624115,
#        'node_id': 'MDQ6VXNlcjU2NjI0MTE1',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/56624115?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/reshuvishwa1705',
#        'html_url': 'https://github.com/reshuvishwa1705',
#        'followers_url': 'https://api.github.com/users/reshuvishwa1705/followers',
#        'following_url': 'https://api.github.com/users/reshuvishwa1705/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/reshuvishwa1705/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/reshuvishwa1705/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/reshuvishwa1705/subscriptions',
#        'organizations_url': 'https://api.github.com/users/reshuvishwa1705/orgs',
#        'repos_url': 'https://api.github.com/users/reshuvishwa1705/repos',
#        'events_url': 'https://api.github.com/users/reshuvishwa1705/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/reshuvishwa1705/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma',
#       'forks_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/forks',
#       'keys_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/teams',
#       'hooks_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/hooks',
#       'issue_events_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/events',
#       'assignees_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/tags',
#       'blobs_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/languages',
#       'stargazers_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/stargazers',
#       'contributors_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/contributors',
#       'subscribers_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/subscribers',
#       'subscription_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/subscription',
#       'commits_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/merges',
#       'archive_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/downloads',
#       'issues_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma/deployments',
#       'created_at': '2019-10-16T12:08:02Z',
#       'updated_at': '2019-12-03T18:31:46Z',
#       'pushed_at': '2019-12-04T01:56:05Z',
#       'git_url': 'git://github.com/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma.git',
#       'ssh_url': 'git@github.com:reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma.git',
#       'clone_url': 'https://github.com/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma.git',
#       'svn_url': 'https://github.com/reshuvishwa1705/USTGlobal-16Sep19-Reshu-Vishwakarma',
#       'homepage': None,
#       'size': 293750,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'HTML',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'master'}},
# ...
#       'contributors_url': 'https://api.github.com/repos/containers/buildah/contributors',
#       'subscribers_url': 'https://api.github.com/repos/containers/buildah/subscribers',
#       'subscription_url': 'https://api.github.com/repos/containers/buildah/subscription',
#       'commits_url': 'https://api.github.com/repos/containers/buildah/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/containers/buildah/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/containers/buildah/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/containers/buildah/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/containers/buildah/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/containers/buildah/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/containers/buildah/merges',
#       'archive_url': 'https://api.github.com/repos/containers/buildah/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/containers/buildah/downloads',
#       'issues_url': 'https://api.github.com/repos/containers/buildah/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/containers/buildah/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/containers/buildah/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/containers/buildah/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/containers/buildah/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/containers/buildah/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/containers/buildah/deployments',
#       'created_at': '2017-01-26T16:59:13Z',
#       'updated_at': '2019-12-04T01:14:45Z',
#       'pushed_at': '2019-12-04T01:56:03Z',
#       'git_url': 'git://github.com/containers/buildah.git',
#       'ssh_url': 'git@github.com:containers/buildah.git',
#       'clone_url': 'https://github.com/containers/buildah.git',
#       'svn_url': 'https://github.com/containers/buildah',
#       'homepage': '',
#       'size': 21932,
#       'stargazers_count': 2476,
#       'watchers_count': 2476,
#       'language': 'Go',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 271,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 96,
#       'license': {'key': 'apache-2.0',
#        'name': 'Apache License 2.0',
#        'spdx_id': 'Apache-2.0',
#        'url': 'https://api.github.com/licenses/apache-2.0',
#        'node_id': 'MDc6TGljZW5zZTI='},
#       'forks': 271,
#       'open_issues': 96,
#       'watchers': 2476,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/containers/buildah/pulls/2004'},
#      'html': {'href': 'https://github.com/containers/buildah/pull/2004'},
#      'issue': {'href': 'https://api.github.com/repos/containers/buildah/issues/2004'},
#      'comments': {'href': 'https://api.github.com/repos/containers/buildah/issues/2004/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/containers/buildah/pulls/2004/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/containers/buildah/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/containers/buildah/pulls/2004/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/containers/buildah/statuses/e3e38a864acbc95f3b052aeed75a566f38b8373e'}},
#     'author_association': 'CONTRIBUTOR',
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 6,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 11,
#     'additions': 190,
#     'deletions': 16,
#     'changed_files': 9}},
#   'public': True,
#   'created_at': '2019-12-04T01:56:05Z',
#   'org': {'id': 5874934,
#    'login': 'containers',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/containers',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5874934?'}},
#  {'id': '11005454663',
#   'type': 'ForkEvent',
#   'actor': {'id': 46062972,
#    'login': 'ShenQingchuan',
#    'display_login': 'ShenQingchuan',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ShenQingchuan',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/46062972?'},
#   'repo': {'id': 27905915,
#    'name': 'HenrikJoreteg/html-parse-stringify',
#    'url': 'https://api.github.com/repos/HenrikJoreteg/html-parse-stringify'},
#   'payload': {'forkee': {'id': 225756034,
#     'node_id': 'MDEwOlJlcG9zaXRvcnkyMjU3NTYwMzQ=',
#     'name': 'html-parse-stringify',
#     'full_name': 'ShenQingchuan/html-parse-stringify',
#     'private': False,
#     'owner': {'login': 'ShenQingchuan',
#      'id': 46062972,
#      'node_id': 'MDQ6VXNlcjQ2MDYyOTcy',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/46062972?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/ShenQingchuan',
#      'html_url': 'https://github.com/ShenQingchuan',
#      'followers_url': 'https://api.github.com/users/ShenQingchuan/followers',
#      'following_url': 'https://api.github.com/users/ShenQingchuan/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/ShenQingchuan/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/ShenQingchuan/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/ShenQingchuan/subscriptions',
#      'organizations_url': 'https://api.github.com/users/ShenQingchuan/orgs',
#      'repos_url': 'https://api.github.com/users/ShenQingchuan/repos',
#      'events_url': 'https://api.github.com/users/ShenQingchuan/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/ShenQingchuan/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/ShenQingchuan/html-parse-stringify',
#     'description': 'Parses well-formed HTML (meaning all tags closed) into an AST and back. quickly.',
#     'fork': True,
#     'url': 'https://api.github.com/repos/ShenQingchuan/html-parse-stringify',
#     'forks_url': 'https://api.github.com/repos/ShenQingchuan/html-parse-stringify/forks',
#     'keys_url': 'https://api.github.com/repos/ShenQingchuan/html-parse-stringify/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/ShenQingchuan/html-parse-stringify/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/ShenQingchuan/html-parse-stringify/teams',
#     'hooks_url': 'https://api.github.com/repos/ShenQingchuan/html-parse-stringify/hooks',
#     'issue_events_url': 'https://api.github.com/repos/ShenQingchuan/html-parse-stringify/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/ShenQingchuan/html-parse-stringify/events',
#     'assignees_url': 'https://api.github.com/repos/ShenQingchuan/html-parse-stringify/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/ShenQingchuan/html-parse-stringify/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/ShenQingchuan/html-parse-stringify/tags',
#     'blobs_url': 'https://api.github.com/repos/ShenQingchuan/html-parse-stringify/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/ShenQingchuan/html-parse-stringify/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/ShenQingchuan/html-parse-stringify/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/ShenQingchuan/html-parse-stringify/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/ShenQingchuan/html-parse-stringify/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/ShenQingchuan/html-parse-stringify/languages',
#     'stargazers_url': 'https://api.github.com/repos/ShenQingchuan/html-parse-stringify/stargazers',
#     'contributors_url': 'https://api.github.com/repos/ShenQingchuan/html-parse-stringify/contributors',
#     'subscribers_url': 'https://api.github.com/repos/ShenQingchuan/html-parse-stringify/subscribers',
#     'subscription_url': 'https://api.github.com/repos/ShenQingchuan/html-parse-stringify/subscription',
#     'commits_url': 'https://api.github.com/repos/ShenQingchuan/html-parse-stringify/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/ShenQingchuan/html-parse-stringify/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/ShenQingchuan/html-parse-stringify/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/ShenQingchuan/html-parse-stringify/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/ShenQingchuan/html-parse-stringify/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/ShenQingchuan/html-parse-stringify/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/ShenQingchuan/html-parse-stringify/merges',
#     'archive_url': 'https://api.github.com/repos/ShenQingchuan/html-parse-stringify/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/ShenQingchuan/html-parse-stringify/downloads',
#     'issues_url': 'https://api.github.com/repos/ShenQingchuan/html-parse-stringify/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/ShenQingchuan/html-parse-stringify/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/ShenQingchuan/html-parse-stringify/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/ShenQingchuan/html-parse-stringify/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/ShenQingchuan/html-parse-stringify/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/ShenQingchuan/html-parse-stringify/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/ShenQingchuan/html-parse-stringify/deployments',
#     'created_at': '2019-12-04T01:56:04Z',
#     'updated_at': '2019-12-04T01:37:11Z',
#     'pushed_at': '2019-11-27T20:03:33Z',
#     'git_url': 'git://github.com/ShenQingchuan/html-parse-stringify.git',
#     'ssh_url': 'git@github.com:ShenQingchuan/html-parse-stringify.git',
#     'clone_url': 'https://github.com/ShenQingchuan/html-parse-stringify.git',
#     'svn_url': 'https://github.com/ShenQingchuan/html-parse-stringify',
#     'homepage': None,
#     'size': 95,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': None,
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'master',
#     'public': True}},
#   'public': True,
#   'created_at': '2019-12-04T01:56:05Z'},
#  {'id': '11005454666',
#   'type': 'WatchEvent',
#   'actor': {'id': 44158548,
#    'login': 'ifarmer',
#    'display_login': 'ifarmer',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ifarmer',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/44158548?'},
#   'repo': {'id': 29753546,
#    'name': 'omadahealth/SwipyRefreshLayout',
#    'url': 'https://api.github.com/repos/omadahealth/SwipyRefreshLayout'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2019-12-04T01:56:05Z',
#   'org': {'id': 1261748,
#    'login': 'omadahealth',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/omadahealth',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1261748?'}},
#  {'id': '11005454644',
#   'type': 'PushEvent',
#   'actor': {'id': 13308861,
#    'login': 'starainDou',
#    'display_login': 'starainDou',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/starainDou',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/13308861?'},
#   'repo': {'id': 139807029,
#    'name': 'starainDou/DDYCategory',
#    'url': 'https://api.github.com/repos/starainDou/DDYCategory'},
#   'payload': {'push_id': 4351951821,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/master',
#    'head': '5009bf27e99bb30e67abe4cd4b17d32c0eb54457',
#    'before': 'd14a1bf1d3416bc7a6e8a649e25bd9e027dea729',
#    'commits': [{'sha': '73b50bad0b6349d98b484dfb4f253ab421dbda37',
#      'author': {'email': 'doudianyu@idengyun.com', 'name': 'rain'},
#      'message': 'Update UIButton+DDYExtension.h',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/starainDou/DDYCategory/commits/73b50bad0b6349d98b484dfb4f253ab421dbda37'},
#     {'sha': '5009bf27e99bb30e67abe4cd4b17d32c0eb54457',
#      'author': {'email': 'doudianyu@idengyun.com', 'name': 'rain'},
#      'message': 'Update UIButton+DDYExtension.m',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/starainDou/DDYCategory/commits/5009bf27e99bb30e67abe4cd4b17d32c0eb54457'}]},
#   'public': True,
#   'created_at': '2019-12-04T01:56:05Z'},
#  {'id': '11005454657',
#   'type': 'CreateEvent',
#   'actor': {'id': 10810283,
#    'login': 'direwolf-github',
#    'display_login': 'direwolf-github',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/direwolf-github',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10810283?'},
#   'repo': {'id': 225756019,
#    'name': 'direwolf-github/my-app-0213ebf5',
#    'url': 'https://api.github.com/repos/direwolf-github/my-app-0213ebf5'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-04T01:56:05Z'},
#  {'id': '11005454649',
#   'type': 'PushEvent',
#   'actor': {'id': 17722683,
#    'login': 'cleverlion',
#    'display_login': 'cleverlion',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cleverlion',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/17722683?'},
#   'repo': {'id': 225753132,
#    'name': 'cleverlion/code-bug-solution',
#    'url': 'https://api.github.com/repos/cleverlion/code-bug-solution'},
#   'payload': {'push_id': 4351951826,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '743e86a233bde8f21e427377a43d700227097a8a',
#    'before': '6a5665ff71219a2aeeb5b7c0bb64e3087eb8c4f1',
#    'commits': [{'sha': '743e86a233bde8f21e427377a43d700227097a8a',
#      'author': {'email': '597066018@qq.com', 'name': 'cleverlion'},
#      'message': 'Create Less in vue-cli',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cleverlion/code-bug-solution/commits/743e86a233bde8f21e427377a43d700227097a8a'}]},
#   'public': True,
#   'created_at': '2019-12-04T01:56:05Z'},
#  {'id': '11005454645',
#   'type': 'PushEvent',
#   'actor': {'id': 1931852,
#    'login': 'hayd',
#    'display_login': 'hayd',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/hayd',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1931852?'},
#   'repo': {'id': 220139138,
#    'name': 'hayd/deno-lambda',
#    'url': 'https://api.github.com/repos/hayd/deno-lambda'},
#   'payload': {'push_id': 4351951823,
#    'size': 2,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '48a382eb994866e2c3089146da707ea4a7d2e9d2',
#    'before': '6978e5f6c6c15635e1b9dae00dc40685179e4877',
#    'commits': [{'sha': '0c198a3241e252712f58ca4d3f2f6ae0e0d96fc4',
#      'author': {'email': 'andyhayden1@gmail.com', 'name': 'Andy Hayden'},
#      'message': 'Fix deno_dir caching of deps and gen\n\n(Take 2)',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/hayd/deno-lambda/commits/0c198a3241e252712f58ca4d3f2f6ae0e0d96fc4'},
#     {'sha': '48a382eb994866e2c3089146da707ea4a7d2e9d2',
#      'author': {'email': 'andyhayden1@gmail.com', 'name': 'Andy Hayden'},
#      'message': 'Merge pull request #13 from hayd/fix-cache\n\nFix deno_dir caching of deps and gen',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/hayd/deno-lambda/commits/48a382eb994866e2c3089146da707ea4a7d2e9d2'}]},
#   'public': True,
#   'created_at': '2019-12-04T01:56:05Z'}]

# %% [markdown]
# ## 其它用法

# %%
payload = {'key1': 'value1', 'key2': 'value2'}
r = requests.get("http://httpbin.org/post", params=payload)
json.loads(r.text)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-8-ecd0fa93eff3> in <module>
#       1 payload = {'key1': 'value1', 'key2': 'value2'}
#       2 r = requests.get("http://httpbin.org/post", params=payload)
# ----> 3 json.loads(r.text)
#
# c:\users\chern\miniconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# c:\users\chern\miniconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# c:\users\chern\miniconda3\lib\json\decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
r = requests.post('http://httpbin.org/post', data = {'key':'value'})
json.loads(r.text)
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'key': 'value'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '9',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.22.0'},
#  'json': None,
#  'origin': '140.113.136.219, 140.113.136.219',
#  'url': 'https://httpbin.org/post'}

# %%
r = requests.post('http://httpbin.org/post', data = {'key':'value'})
json.loads(r.text)

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)
